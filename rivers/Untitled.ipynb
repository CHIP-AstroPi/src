# %%
from matplotlib import pyplot as plt
import cv2

img = cv2.imread('/home/popaii/Documents/astropi/src/rivers/data/46139865612_61080b4f33_o.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img[:,:,::-1])
plt.title('my picture')
plt.show()
